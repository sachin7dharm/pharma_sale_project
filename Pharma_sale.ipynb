# %% [markdown]
# This dataset is downloded from Kaggle https://www.kaggle.com/datasets/yogeshpandey1/pharma-sales-hourly?select=saleshourly1.csv
#
# M01AB - Anti-inflammatory and antirheumatic products, non-steroids; Acetic acid derivatives and related substances
# M01AE - Anti-inflammatory and antirheumatic products, non-steroids; Propionic acid derivatives
# N02BA - Other analgesics and antipyretics; Salicylic acid and derivatives
# N02BE - Other analgesics and antipyretics; Pyrazolones and Anilides
# N05B - Psycholeptics drugs, Anxiolytic drugs
# N05C - Psycholeptics drugs, Hypnotics and sedatives drugs
# R03 - Drugs for obstructive airway diseases
# R06 - Antihistamines for systemic use

# %%
# importing Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading dataset
df=pd.read_csv(r"C:\Users\sachi\Downloads\saleshourly1.csv\saleshourly1.csv")
df
# Out:
#                   datum              date  M01AB  M01AE  N02BA  N02BE  N05B  \
# 0      01-02-2014 08:00  02-01-2014 08:00   0.00   0.67    0.4    2.0   0.0
# 1      01-02-2014 09:00  02-01-2014 09:00   0.00   0.00    1.0    0.0   2.0
# 2      01-02-2014 10:00  02-01-2014 10:00   0.00   0.00    0.0    3.0   2.0
# 3      01-02-2014 11:00  02-01-2014 11:00   0.00   0.00    0.0    2.0   1.0
# 4      01-02-2014 12:00  02-01-2014 12:00   0.00   2.00    0.0    5.0   2.0
# ...                 ...               ...    ...    ...    ...    ...   ...
# 50527  10-08-2019 15:00  08-10-2019 15:00   0.00   0.40    0.0   11.3   1.0
# 50528  10-08-2019 16:00  08-10-2019 16:00   0.33   0.00    0.0    1.0   2.0
# 50529  10-08-2019 17:00  08-10-2019 17:00   0.00   0.00    0.0    1.0   2.0
# 50530  10-08-2019 18:00  08-10-2019 18:00   0.00   0.00    0.0    9.0   0.0
# 50531  10-08-2019 19:00  08-10-2019 19:00   0.00   0.33    0.0    8.0   1.0
#
#        N05C  R03  R06  Year  Month  Hour Weekday Name
# ...

# %%
# top 5 rows
df.head()
# Out:
#               datum              date  M01AB  M01AE  N02BA  N02BE  N05B  N05C  \
# 0  01-02-2014 08:00  02-01-2014 08:00    0.0   0.67    0.4    2.0   0.0   0.0
# 1  01-02-2014 09:00  02-01-2014 09:00    0.0   0.00    1.0    0.0   2.0   0.0
# 2  01-02-2014 10:00  02-01-2014 10:00    0.0   0.00    0.0    3.0   2.0   0.0
# 3  01-02-2014 11:00  02-01-2014 11:00    0.0   0.00    0.0    2.0   1.0   0.0
# 4  01-02-2014 12:00  02-01-2014 12:00    0.0   2.00    0.0    5.0   2.0   0.0
#
#    R03  R06  Year  Month  Hour Weekday Name
# 0  0.0  1.0  2014      1     8     Thursday
# 1  0.0  0.0  2014      1     9     Thursday
# 2  0.0  0.0  2014      1    10     Thursday
# 3  0.0  0.0  2014      1    11     Thursday
# 4  0.0  0.0  2014      1    12     Thursday

# %%
#last 5 rows

df.tail()
# Out:
#                   datum              date  M01AB  M01AE  N02BA  N02BE  N05B  \
# 50527  10-08-2019 15:00  08-10-2019 15:00   0.00   0.40    0.0   11.3   1.0
# 50528  10-08-2019 16:00  08-10-2019 16:00   0.33   0.00    0.0    1.0   2.0
# 50529  10-08-2019 17:00  08-10-2019 17:00   0.00   0.00    0.0    1.0   2.0
# 50530  10-08-2019 18:00  08-10-2019 18:00   0.00   0.00    0.0    9.0   0.0
# 50531  10-08-2019 19:00  08-10-2019 19:00   0.00   0.33    0.0    8.0   1.0
#
#        N05C  R03  R06  Year  Month  Hour Weekday Name
# 50527   0.0  0.0  0.0  2019     10    15      Tuesday
# 50528   0.0  0.0  0.0  2019     10    16      Tuesday
# 50529   0.0  1.0  0.0  2019     10    17      Tuesday
# 50530   0.0  0.0  0.0  2019     10    18      Tuesday
# 50531   0.0  1.0  0.0  2019     10    19      Tuesday

# %%
# checking null values

df.isna().sum()
# Out:
# datum           0
# date            0
# M01AB           0
# M01AE           0
# N02BA           0
# N02BE           0
# N05B            0
# N05C            0
# R03             0
# R06             0
# Year            0
# Month           0
# Hour            0
# Weekday Name    0
# dtype: int64

# %%
# data information

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50532 entries, 0 to 50531
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   datum         50532 non-null  object
#  1   date          50532 non-null  object
#  2   M01AB         50532 non-null  float64
#  3   M01AE         50532 non-null  float64
#  4   N02BA         50532 non-null  float64
#  5   N02BE         50532 non-null  float64
#  6   N05B          50532 non-null  float64
#  7   N05C          50532 non-null  float64
#  8   R03           50532 non-null  float64
#  9   R06           50532 non-null  float64
#  10  Year          50532 non-null  int64
#  11  Month         50532 non-null  int64
#  12  Hour          50532 non-null  int64
#  13  Weekday Name  50532 non-null  object
# dtypes: float64(8), int64(3), object(3)
# memory usage: 5.4+ MB

# %%
# data description
df.describe()
# Out:
#               M01AB         M01AE         N02BA         N02BE          N05B  \
# count  50532.000000  50532.000000  50532.000000  50532.000000  50532.000000
# mean       0.209787      0.162365      0.161723      1.246842      0.368989
# std        0.556003      0.416109      0.453211      2.387392      0.930934
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      1.875000      0.000000
# max        7.000000      6.000000      6.500000     29.000000     15.000000
#
#                N05C           R03           R06          Year         Month  \
# count  50532.000000  50532.000000  50532.000000  50532.000000  50532.000000
# mean       0.024736      0.229732      0.120870   2016.401409      6.344811
# ...

# %%
#creating a list of Medicines

l=list(df.columns)
l1=l[2:10]
l1
# Out:
# ['M01AB', 'M01AE', 'N02BA', 'N02BE', 'N05B', 'N05C', 'R03', 'R06']

# %%
# yearly sale

ydf=df.groupby('Year')[l1].sum().reset_index()
for medicine in l1:
    plt.plot(ydf['Year'],ydf[medicine],label=medicine,marker='o')
plt.title('Medicine Sales by Yearly')
plt.xlabel('Year')
plt.ylabel('Sales')
plt.legend(loc='center')
plt.grid()
plt.show()

# %%
# Average sale by yearly

avg_ydf=df.groupby('Year')[l1].mean().reset_index()
avg_ydf
# Out:
#    Year     M01AB     M01AE     N02BA     N02BE      N05B      N05C       R03  \
# 0  2014  0.165813  0.144031  0.185205  1.062600  0.494393  0.031236  0.143790
# 1  2015  0.216395  0.170845  0.183634  1.361099  0.338470  0.018151  0.196490
# 2  2016  0.239900  0.180947  0.188435  1.518167  0.357278  0.023566  0.243283
# 3  2017  0.210801  0.158367  0.147066  1.056941  0.291729  0.020586  0.216166
# 4  2018  0.203987  0.158637  0.128288  1.282069  0.372854  0.026826  0.303111
# 5  2019  0.225114  0.160907  0.130534  1.184346  0.356914  0.029080  0.288829
#
#         R06
# 0  0.091715
# 1  0.112218
# 2  0.121251
# 3  0.112884
# 4  0.136621
# 5  0.159283

# %%
for medicine in l1:
    plt.plot(avg_ydf['Year'],avg_ydf[medicine],label=medicine,marker='o')
plt.title('Medicine Average Sale by Yearly')
plt.xlabel('Year')
plt.ylabel('Average Sales')
plt.legend()
plt.grid()
plt.show()

# %%
#yearly month wise medicine sale

ymdf=df.groupby(['Year','Month'])[l1].sum().reset_index()
ymdf
# Out:
#     Year  Month   M01AB    M01AE    N02BA     N02BE   N05B  N05C         R03  \
# 0   2014      1  127.69   99.090  152.100   878.030  354.0  30.0  112.000000
# 1   2014      2  133.32  126.050  177.000  1001.900  347.0  31.0  122.000000
# 2   2014      3  137.44   92.950  147.655   779.275  232.0  20.0  112.000000
# 3   2014      4  113.10   89.475  125.150   698.500  209.0  18.0   97.000000
# 4   2014      5  101.79  119.933  132.100   628.780  270.0  23.0  107.000000
# ..   ...    ...     ...      ...      ...       ...    ...   ...         ...
# 65  2019      6  151.54  101.627  103.200   610.000  193.0  25.0  142.000000
# 66  2019      7  181.00  103.541   92.800   620.675  250.6  20.0  115.000000
# 67  2019      8  181.91   88.269   84.200   518.100  237.0  26.0  145.000000
# 68  2019      9  161.07  111.437   93.500   984.480  227.8  16.0  121.416667
# 69  2019     10   44.37   37.300   20.650   295.150   86.0   7.0   37.000000
#
#        R06
# 0    48.20
# 1    36.20
# ...

# %%
# M01AB medicine sale 

color={2014:'Green',2015:'Red',2016:'Blue',2017:'Brown',2018:'Orange',2019:'Purple'}

sns.catplot(x='Month',y=ymdf['M01AB'],data=ymdf,hue='Year',palette=color,s=40,linewidth=0.8)
plt.grid()
plt.show()

# %%
# M01AE medicine sale 

sns.catplot(x='Month',y=ymdf['M01AE'],hue='Year',data=ymdf,palette=color,s=40,linewidth=0.8)
plt.grid()
plt.show()

# %%
# N02BA  medicine sale 

sns.catplot(x='Month',y=ymdf['N02BA'],data=ymdf,hue='Year',palette=color,s=40,linewidth=0.8)
plt.grid()
plt.show()

# %%
#N02BE medicine sale 

sns.catplot(x='Month',y=ymdf['N02BE'],data=ymdf,hue='Year',palette=color,s=40,linewidth=0.8)
plt.grid()
plt.show()

# %%
# N05B medicine sale 

sns.catplot(x='Month',y=ymdf['N05B'],data=ymdf,hue='Year',palette=color,s=40,linewidth=0.8)
plt.grid()
plt.show()

# %%
#N05C medicine sale 

sns.catplot(x='Month',y=ymdf['N05C'],data=ymdf,hue='Year',palette=color,s=40,linewidth=0.8)
plt.grid()
plt.show()

# %%
# R03 medicine sale 

sns.catplot(x='Month',y=ymdf['R03'],data=ymdf,hue='Year',palette=color,s=40,linewidth=0.8)
plt.grid()
plt.show()

# %%
# R06 medicine sale 

sns.catplot(x='Month',y=ymdf['R06'],data=ymdf,hue='Year',palette=color,s=40,linewidth=0.8)
plt.grid()
plt.show()

# %%
# total hourly sale from 2014 to 2019

hdf=df.groupby('Hour')[l1].sum().reset_index()
for medicine in l1:
    plt.plot(hdf['Hour'],hdf[medicine],label=medicine,marker='o')
plt.title('Medicine Sales by Hourly')
plt.xlabel('Hour')
plt.ylabel('Sales')
plt.legend()
plt.grid()
plt.show()

# %%
# total monthly sale from 2014 to 2019

mdf=df.groupby('Month')[l1].sum().reset_index()
for medicine in l1:
    plt.plot(mdf['Month'],mdf[medicine],label=medicine,marker='o')
plt.title('Medicine Sales by Month')
plt.xlabel('Month')
plt.ylabel('Sales')
plt.legend()
plt.grid()
plt.show()
